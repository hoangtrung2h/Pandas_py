# %%
import pandas as pd

# %%
st=pd.read_csv("student-mat.csv",sep=';')

# %%
st.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
st.shape
st.info
# Out:
# <bound method DataFrame.info of     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
st.rpow
# Out:
# <bound method flex_arith_method_FRAME.<locals>.f of     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
st.rmod
# Out:
# <bound method flex_arith_method_FRAME.<locals>.f of     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
st.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
st.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
st.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
teacher=st.loc[(st.sex=='F')&(st["Fjob"]=="teacher")]
teacher
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home  teacher
# 7       GP   F   17       U     GT3       A     4     4     other  teacher
# 49      GP   F   15       U     GT3       T     4     4  services  teacher
# 60      GP   F   16       R     GT3       T     4     4    health  teacher
# 130     GP   F   15       R     GT3       T     3     4  services  teacher
# 139     GP   F   15       U     GT3       T     4     4   teacher  teacher
# 154     GP   F   17       U     GT3       T     4     4     other  teacher
# 198     GP   F   17       U     GT3       T     4     4  services  teacher
# 199     GP   F   16       U     LE3       T     4     4   teacher  teacher
# 222     GP   F   16       U     GT3       T     2     3  services  teacher
# 287     GP   F   17       U     GT3       T     1     1  services  teacher
# ...

# %%
teacher.iloc[:,0:10]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob
# 0       GP   F   18       U     GT3       A     4     4   at_home  teacher
# 7       GP   F   17       U     GT3       A     4     4     other  teacher
# 49      GP   F   15       U     GT3       T     4     4  services  teacher
# 60      GP   F   16       R     GT3       T     4     4    health  teacher
# 130     GP   F   15       R     GT3       T     3     4  services  teacher
# 139     GP   F   15       U     GT3       T     4     4   teacher  teacher
# 154     GP   F   17       U     GT3       T     4     4     other  teacher
# 198     GP   F   17       U     GT3       T     4     4  services  teacher
# 199     GP   F   16       U     LE3       T     4     4   teacher  teacher
# 222     GP   F   16       U     GT3       T     2     3  services  teacher
# 287     GP   F   17       U     GT3       T     1     1  services  teacher
# ...

# %%
study_time=st.loc[(st.studytime>3)]['school']
study_time
# Out:
# 47     GP
# 66     GP
# 67     GP
# 69     GP
# 70     GP
# 71     GP
# 76     GP
# 77     GP
# 94     GP
# 95     GP
# 105    GP
# 106    GP
# 108    GP
# 121    GP
# 140    GP
# 204    GP
# 210    GP
# 256    GP
# 259    GP
# 271    GP
# 282    GP
# 293    GP
# 298    GP
# 303    GP
# 330    GP
# 334    GP
# 338    GP
# Name: school, dtype: object

# %%
st['age'].nunique()
# Out:
# 8

# %%
st.age.unique()
# Out:
# array([18, 17, 15, 16, 19, 22, 20, 21], dtype=int64)

# %%
# caculate sum of each group
a=st.groupby('Fjob')["health"].sum()
a
# Out:
# Fjob
# at_home      69
# health       73
# other       771
# services    385
# teacher     106
# Name: health, dtype: int64

# %%
a.sort_values()
# Out:
# Fjob
# at_home      69
# health       73
# teacher     106
# services    385
# other       771
# Name: health, dtype: int64

# %%
st.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
a=st['absences']
a.sort_values(ascending=False)
# Out:
# 276    75
# 183    56
# 74     54
# 315    40
# 307    38
#        ..
# 56      0
# 167     0
# 168     0
# 269     0
# 131     0
# Name: absences, Length: 395, dtype: int64

# %%
st.iloc[276,:]
# Out:
# school              GP
# sex                  F
# age                 18
# address              R
# famsize            GT3
# Pstatus              A
# Medu                 3
# Fedu                 2
# Mjob             other
# Fjob          services
# reason            home
# guardian        mother
# traveltime           2
# studytime            2
# failures             0
# schoolsup           no
# famsup              no
# paid                no
# activities          no
# nursery             no
# higher              no
# internet           yes
# romantic           yes
# famrel               4
# freetime             1
# goout                1
# Dalc                 1
# Walc                 1
# health               5
# absences            75
# G1                  10
# G2                   9
# G3                   9
# Name: 276, dtype: object

# %%
st.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
st.loc[(st.sex!='F')&(st.age==18)]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 128     GP   M   18       R     GT3       T     2     2  services     other
# 150     GP   M   18       U     LE3       T     1     1     other     other
# 213     GP   M   18       U     GT3       T     2     2  services     other
# 217     GP   M   18       U     LE3       T     3     3  services    health
# 223     GP   M   18       U     GT3       T     2     2     other     other
# 228     GP   M   18       U     LE3       T     2     1   at_home     other
# 239     GP   M   18       U     GT3       T     2     2     other  services
# 248     GP   M   18       R     LE3       T     3     3     other  services
# 250     GP   M   18       U     GT3       T     3     2  services     other
# 252     GP   M   18       U     GT3       T     2     1  services  services
# 258     GP   M   18       U     GT3       T     2     1     other     other
# ...

# %%
a=st.groupby('age')['sex']
a.count()
# Out:
# age
# 15     82
# 16    104
# 17     98
# 18     82
# 19     24
# 20      3
# 21      1
# 22      1
# Name: sex, dtype: int64

# %%
age=st.loc[(st.sex=='F')].count()
age
# Out:
# school        208
# sex           208
# age           208
# address       208
# famsize       208
# Pstatus       208
# Medu          208
# Fedu          208
# Mjob          208
# Fjob          208
# reason        208
# guardian      208
# traveltime    208
# studytime     208
# failures      208
# schoolsup     208
# famsup        208
# paid          208
# activities    208
# nursery       208
# higher        208
# internet      208
# romantic      208
# famrel        208
# freetime      208
# goout         208
# Dalc          208
# Walc          208
# health        208
# absences      208
# G1            208
# G2            208
# G3            208
# dtype: int64

# %%
woman=st.groupby(['sex','age'])
woman.count()
# woman.first()
# Out:
#          school  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  reason  \
# sex age
# F   15       38       38       38       38    38    38    38    38      38
#     16       54       54       54       54    54    54    54    54      54
#     17       58       58       58       58    58    58    58    58      58
#     18       43       43       43       43    43    43    43    43      43
#     19       14       14       14       14    14    14    14    14      14
#     20        1        1        1        1     1     1     1     1       1
# M   15       44       44       44       44    44    44    44    44      44
#     16       50       50       50       50    50    50    50    50      50
#     17       40       40       40       40    40    40    40    40      40
#     18       39       39       39       39    39    39    39    39      39
#     19       10       10       10       10    10    10    10    10      10
# ...

# %%
st["school"]
# Out:
# 0      GP
# 1      GP
# 2      GP
# 3      GP
# 4      GP
#        ..
# 390    MS
# 391    MS
# 392    MS
# 393    MS
# 394    MS
# Name: school, Length: 395, dtype: object

# %%
st.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
st.shape
# Out:
# (395, 33)
