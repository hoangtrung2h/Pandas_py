# %%
import pandas as pd

# %%
st=pd.read_csv("Book1.csv",sep=',')

# %%
st.head()
# Out:
#    Số thứ tự Lớp 12       Số CMND         Họ và tên Giới tính   Ngày sinh  \
# 0          1   12A1     188043705     NGUYỄN TÂM AN       Nam  15/05/2003
# 1          2   12A1     188043624    NGÔ SỸ ĐỨC ANH       Nam  24/09/2003
# 2          3   12A1  040303007095   NGUYỄN THẢO ANH        Nữ  02/08/2003
# 3          4   12A1     188043644  TĂNG THỊ VÂN ANH        Nữ  09/11/2003
# 4          5   12A1     188042585     TĂNG NGỌC ÁNH       Nam  23/11/2003
#
#   Nơi sinh Dân tộc                   Mã_Tên hội đồng  Toán  ...  Vật lí  \
# 0  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.8  ...    9.50
# 1  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   9.6  ...    4.25
# 2  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.6  ...    6.25
# 3  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.4  ...    8.75
# 4  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   9.2  ...    8.00
#
#    Hóa học  Sinh học  Lịch sử  Địa lý  GDCD  Ngoại ngữ  Môn NN Ghi chú  \
# 0     9.25      3.50      NaN     NaN   NaN        4.6      N1     NaN
# 1     9.00      9.75      NaN     NaN   NaN        5.6      N1     NaN
# 2     7.75      7.50      NaN     NaN   NaN        6.2      N1     NaN
# 3     9.00      5.00      NaN     NaN   NaN        7.4      N1     NaN
# 4     9.50      5.50      NaN     NaN   NaN        3.6      N1     NaN
#
#    Ghi chu
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 21 columns]

# %%
st.head(12)
# Out:
#     Số thứ tự Lớp 12       Số CMND          Họ và tên Giới tính   Ngày sinh  \
# 0           1   12A1     188043705      NGUYỄN TÂM AN       Nam  15/05/2003
# 1           2   12A1     188043624     NGÔ SỸ ĐỨC ANH       Nam  24/09/2003
# 2           3   12A1  040303007095    NGUYỄN THẢO ANH        Nữ  02/08/2003
# 3           4   12A1     188043644   TĂNG THỊ VÂN ANH        Nữ  09/11/2003
# 4           5   12A1     188042585      TĂNG NGỌC ÁNH       Nam  23/11/2003
# 5           6   12A1     188043539  NGUYỄN THÀNH BANG       Nam  17/01/2003
# 6           7   12A1     187995537      VƯƠNG GIA BẢO       Nam  21/04/2003
# 7           8   12A1     188043524       VÕ HOÀN CHÂU       Nam  03/02/2003
# 8           9   12A1     188043730   NGUYỄN MẠNH DŨNG       Nam  11/09/2003
# 9          10   12A1     188043729      NGÔ THỊ DUYÊN        Nữ  12/12/2003
# 10         11   12A1     188043642  NGUYỄN CẢNH DƯƠNG       Nam  25/08/2003
# 11         12   12A1     188043646    PHAN THÁI DƯƠNG       Nam  21/10/2003
#
#    Nơi sinh Dân tộc                   Mã_Tên hội đồng  Toán  ...  Vật lí  \
# 0   NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.8  ...    9.50
# 1   NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   9.6  ...    4.25
# 2   NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.6  ...    6.25
# 3   NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.4  ...    8.75
# 4   NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   9.2  ...    8.00
# 5   NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   9.0  ...    9.25
# 6   NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   7.6  ...    5.75
# 7   NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.4  ...    4.75
# 8   NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   9.4  ...    9.00
# 9   NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   9.0  ...    6.25
# 10  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   9.0  ...    8.50
# 11  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   9.0  ...    7.75
#
#     Hóa học  Sinh học  Lịch sử  Địa lý  GDCD  Ngoại ngữ  Môn NN Ghi chú  \
# 0      9.25      3.50      NaN     NaN   NaN        4.6      N1     NaN
# 1      9.00      9.75      NaN     NaN   NaN        5.6      N1     NaN
# 2      7.75      7.50      NaN     NaN   NaN        6.2      N1     NaN
# 3      9.00      5.00      NaN     NaN   NaN        7.4      N1     NaN
# 4      9.50      5.50      NaN     NaN   NaN        3.6      N1     NaN
# 5      8.75      4.50      NaN     NaN   NaN        7.2      N1     NaN
# 6      6.50      4.00      NaN     NaN   NaN        5.0      N1     NaN
# 7      9.00      8.75      NaN     NaN   NaN        4.0      N1     NaN
# 8      8.25      6.00      NaN     NaN   NaN        5.6      N1     NaN
# 9      9.25      9.00      NaN     NaN   NaN        7.8      N1     NaN
# 10     7.75      5.50      NaN     NaN   NaN        5.2      N1     NaN
# 11     8.75      4.50      NaN     NaN   NaN        8.4      N1     NaN
#
#     Ghi chu
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
#
# [12 rows x 21 columns]

# %%
st.columns
# Out:
# Index(['Số thứ tự', 'Lớp 12', 'Số CMND', 'Họ và tên', 'Giới tính', 'Ngày sinh',
#        'Nơi sinh', 'Dân tộc', 'Mã_Tên hội đồng', 'Toán', 'Ngữ văn', 'Vật lí',
#        'Hóa học', 'Sinh học', 'Lịch sử', 'Địa lý', 'GDCD', 'Ngoại ngữ',
#        'Môn NN', 'Ghi chú', 'Ghi chu'],
#       dtype='object')

# %%
st.columns
# Out:
# Index(['Số thứ tự', 'Lớp 12', 'Số CMND', 'Họ và tên', 'Giới tính', 'Ngày sinh',
#        'Nơi sinh', 'Dân tộc', 'Mã_Tên hội đồng', 'Toán', 'Ngữ văn', 'Vật lí',
#        'Hóa học', 'Sinh học', 'Lịch sử', 'Địa lý', 'GDCD', 'Ngoại ngữ',
#        'Môn NN', 'Ghi chú', 'Ghi chu'],
#       dtype='object')

# %%
st.head()
# Out:
#    Số thứ tự Lớp 12       Số CMND         Họ và tên Giới tính   Ngày sinh  \
# 0          1   12A1     188043705     NGUYỄN TÂM AN       Nam  15/05/2003
# 1          2   12A1     188043624    NGÔ SỸ ĐỨC ANH       Nam  24/09/2003
# 2          3   12A1  040303007095   NGUYỄN THẢO ANH        Nữ  02/08/2003
# 3          4   12A1     188043644  TĂNG THỊ VÂN ANH        Nữ  09/11/2003
# 4          5   12A1     188042585     TĂNG NGỌC ÁNH       Nam  23/11/2003
#
#   Nơi sinh Dân tộc                   Mã_Tên hội đồng  Toán  ...  Vật lí  \
# 0  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.8  ...    9.50
# 1  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   9.6  ...    4.25
# 2  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.6  ...    6.25
# 3  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.4  ...    8.75
# 4  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   9.2  ...    8.00
#
#    Hóa học  Sinh học  Lịch sử  Địa lý  GDCD  Ngoại ngữ  Môn NN Ghi chú  \
# 0     9.25      3.50      NaN     NaN   NaN        4.6      N1     NaN
# 1     9.00      9.75      NaN     NaN   NaN        5.6      N1     NaN
# 2     7.75      7.50      NaN     NaN   NaN        6.2      N1     NaN
# 3     9.00      5.00      NaN     NaN   NaN        7.4      N1     NaN
# 4     9.50      5.50      NaN     NaN   NaN        3.6      N1     NaN
#
#    Ghi chu
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 21 columns]

# %%
st.count
# Out:
# <bound method DataFrame.count of      Số thứ tự Lớp 12       Số CMND               Họ và tên Giới tính  \
# 0            1   12A1     188043705           NGUYỄN TÂM AN       Nam
# 1            2   12A1     188043624          NGÔ SỸ ĐỨC ANH       Nam
# 2            3   12A1  040303007095         NGUYỄN THẢO ANH        Nữ
# 3            4   12A1     188043644        TĂNG THỊ VÂN ANH        Nữ
# 4            5   12A1     188042585           TĂNG NGỌC ÁNH       Nam
# ..         ...    ...           ...                     ...       ...
# 556        557  12TDO     187829497      CAO THỊ DIỄM QUỲNH        Nữ
# 557        558  12TDO     187788033         NGUYỄN ĐỨC SANG       Nam
# 558        559  12TDO     187892127  NGUYỄN THỊ PHƯƠNG THẢO        Nữ
# 559        560  12TDO     187892138         VÕ THỊ THU THỦY        Nữ
# 560        561  12TDO     187892147        NGUYỄN XUÂN TUẤN       Nam
#
#       Ngày sinh Nơi sinh Dân tộc                   Mã_Tên hội đồng  Toán  ...  \
# 0    15/05/2003  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.8  ...
# 1    24/09/2003  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   9.6  ...
# 2    02/08/2003  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.6  ...
# 3    09/11/2003  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.4  ...
# 4    23/11/2003  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   9.2  ...
# ..          ...      ...     ...                               ...   ...  ...
# 556  02/10/2002  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.6  ...
# 557  06/10/2001  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.2  ...
# 558  03/04/2002  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.6  ...
# 559  24/09/2002  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   7.4  ...
# 560  06/07/2002  NGHỆ AN    Kinh  29-Hội đồng thi Sở GD&ĐT Nghệ An   8.0  ...
#
#      Vật lí  Hóa học  Sinh học  Lịch sử  Địa lý  GDCD  Ngoại ngữ  Môn NN  \
# 0      9.50     9.25      3.50      NaN     NaN   NaN        4.6      N1
# 1      4.25     9.00      9.75      NaN     NaN   NaN        5.6      N1
# 2      6.25     7.75      7.50      NaN     NaN   NaN        6.2      N1
# 3      8.75     9.00      5.00      NaN     NaN   NaN        7.4      N1
# 4      8.00     9.50      5.50      NaN     NaN   NaN        3.6      N1
# ..      ...      ...       ...      ...     ...   ...        ...     ...
# 556    7.25     7.25       NaN      NaN     NaN   NaN        NaN     NaN
# 557    7.50     7.25       NaN      NaN     NaN   NaN        NaN     NaN
# 558     NaN     7.75      9.50      NaN     NaN   NaN        NaN     NaN
# 559     NaN     6.75      7.75      NaN     NaN   NaN        NaN     NaN
# 560     NaN     7.50      8.25      NaN     NaN   NaN        NaN     NaN
#
#     Ghi chú  Ghi chu
# 0       NaN      NaN
# 1       NaN      NaN
# 2       NaN      NaN
# 3       NaN      NaN
# 4       NaN      NaN
# ..      ...      ...
# 556     NaN      NaN
# 557     NaN      NaN
# 558     NaN      NaN
# 559     NaN      NaN
# 560     NaN      NaN
#
# [561 rows x 21 columns]>

# %%
st.shape
# Out:
# (561, 21)

# %%
st.columns
# Out:
# Index(['Số thứ tự', 'Lớp 12', 'Số CMND', 'Họ và tên', 'Giới tính', 'Ngày sinh',
#        'Nơi sinh', 'Dân tộc', 'Mã_Tên hội đồng', 'Toán', 'Ngữ văn', 'Vật lí',
#        'Hóa học', 'Sinh học', 'Lịch sử', 'Địa lý', 'GDCD', 'Ngoại ngữ',
#        'Môn NN', 'Ghi chú', 'Ghi chu'],
#       dtype='object')

# %%
pd.set_option('display.max_colwidth', None)

# %%
Gdcd=st.loc[st['GDCD']>=9]

# %%
Gdcd.to_csv("Điểm 9,10.csv")

# %%
df1 = pd.DataFrame([['a', 'b'], ['c', 'd']],
                   index=['row 1', 'row 2'],
                   columns=['col 1', 'col 2'])

# %%
df1
# Out:
#       col 1 col 2
# row 1     a     b
# row 2     c     d

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
df1 = pd.DataFrame([['a', 'b'], ['c', 'd']],
                   index=['row 1', 'row 2'],
                   columns=['col 1', 'col 2'])
df1.to_excel("output.xlsx")

# %%
Gdcd.to_excel("gdcd.xlsx")
